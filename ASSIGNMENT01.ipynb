# %% [markdown]
# # Assignment on Python for Data Science

# %%
#import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1
# Read the dataset to python environment

# %%
#Read the dataset
data = pd.read_excel(r'C:\Users\HP\Downloads\iris.xlsx')

# %%
#display the data
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2
# Display the columns in the dataset.

# %%
#display the columns of the data
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3
# Calculate the mean of each column of the dataset

# %%
#finding the mean of each column of the data using mean()
data.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2688\1187401472.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4
#
# Check for the null values present in the dataset.

# %%
#display the null values of the data
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5
#
# Perform meaningful visualizations using the dataset.

# %% [markdown]
# # a.

# %%
# using seaborn displaying the graph
sns.countplot(data,x='Classification')

#using matplotlib,

#set title of the graph,size and colour
plt.title('DATA OF CLASSIFICATIONS',size=20,color='r')

#set xlabel and ylabel of the graph
plt.xlabel('CLASSIFICATIONS')
plt.ylabel('COUNT')

#show the plot
plt.show()

# %% [markdown]
# # b.

# %%
# using matplotlib,

#displaying the graph with classification and sl
plt.bar(data['Classification'],data['SL'])


#set title of the graph with size and colour
plt.title('BAR GRAPH OF SEPAL LENGTH',size=20,color='r')

#set xlabel and ylabel of the graph
plt.xlabel('CLASSIFICATION OF SPECIES')
plt.ylabel('SEPAL LENGTH (SL)')

#show the plot
plt.show()

# %% [markdown]
# # C.

# %%
#using matplotlib,

#plot the figure with a size 
plt.figure(figsize=(10,4))

#displaying the sepal width as histogram with colour and width 
plt.hist(data['SW'],color='y',rwidth=.8)

#set title of the graph with size and colour
plt.title('HISTOGRAM OF SEPAL WIDTH',size=25,color='g')

#set xlabel and ylabel of the graph
plt.xlabel('SW')
plt.ylabel('count')

#show the plot
plt.show()

# %% [markdown]
# # d.

# %%
#create boxplot for petal length
plt.boxplot(data['PL'])

#set title of the plot with size and colour
plt.title('BOXPLOT OF PETAL LENGTH',size=18,c='y')

#show the plot
plt.show()

# %% [markdown]
# # e.

# %%
#by using seaborn pairplot the data
sns.pairplot(data)

#show the plot
plt.show()

# %% [markdown]
# # f.

# %%
#by using seaborn create a boxplot of sl,sw,pl,pw
sns.boxplot(data)

#show the plot
plt.show()

# %% [markdown]
# # g.

# %%
# by using seaborn creating a boxplot of petal width 
sns.boxplot(x='Classification',y='PW',data=data)

#show the plot
plt.show()

# %% [markdown]
# # h.

# %%
#Creating a scatter plot of sepal length with size,marker & colour
plt.scatter(data['Classification'],data['SL'],s=10,marker='x',color='b')

#set title of the scatter plot with size and colour
plt.title('SCATTER PLOT OF SEPAL LENGTH',size=18,c='g')

#show the plot
plt.show()
